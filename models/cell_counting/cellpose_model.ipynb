# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pip install cellpose==3.0.8

# %% [markdown]
# #Training wit annotated dataset.

# %%
FOLDER_NAME = "annotated"

# !unzip "/content/drive/MyDrive/{FOLDER_NAME}.zip" -d "/content"

# %%
import numpy as np
import glob
import cv2
from torch.utils.data import Dataset, random_split

file_names = glob.glob(FOLDER_NAME + "/*.jpg")

class ImageDataset(Dataset):
  def __len__(self):
    return len(file_names)

  def __getitem__(self, idx):
    img = cv2.imread(file_names[idx], 0)
    mask = np.load(file_names[idx].replace(".jpg", "_seg.npy"), allow_pickle=True).item()["masks"]
    return img, mask

dataset = ImageDataset()

training_dataset, test_dataset = random_split(dataset, [0.8, 0.2])

# %%
# Getting training and test data into memory.
# In future maybe an own training loop can be implemented if memory is not enough.
training_images, training_masks = [], []

for image, mask in training_dataset:
  training_images.append(image)
  training_masks.append(mask)

test_images, test_masks = [], []
for image, mask in test_dataset:
  test_images.append(image)
  test_masks.append(mask)

# %%
from cellpose import models, train, utils, transforms, dynamics
from tqdm import trange
import torch
import logging

def train_model(model_type, n_epochs):
  logger = logging.getLogger('cellpose')
  logger.setLevel(logging.DEBUG)

  model = models.CellposeModel(model_type=model_type, gpu=torch.cuda.is_available())
  test_labels = dynamics.labels_to_flows(test_masks, device=model.net.device)

  train.train_seg(
              model.net, n_epochs=n_epochs,
              train_data=training_images, train_labels=training_masks,
              test_data=test_images, test_labels=test_masks,
              channels=[0, 0], normalize=True,
              weight_decay=1e-4, SGD=True, learning_rate=0.1,
              save_path="/content/drive/MyDrive/cellpose-cell-counting", model_name=f"{model_type}")

# %%
train_model("cyto3", n_epochs = 1000)
# Out:
# INFO:cellpose.models:>> cyto3 << model set to be used
# INFO:cellpose.core:** TORCH CUDA version installed and working. **
# INFO:cellpose.core:>>>> using GPU
# INFO:cellpose.models:>>>> loading model /root/.cellpose/models/cyto3
# INFO:cellpose.models:>>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# INFO:cellpose.dynamics:computing flows for labels
# 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:cellpose.dynamics:computing flows for labels
# 100%|██████████| 13/13 [00:08<00:00,  1.54it/s]
# INFO:cellpose.dynamics:computing flows for labels
# 100%|██████████| 3/3 [00:01<00:00,  1.72it/s]
# INFO:cellpose.train:>>> computing diameters
# 100%|██████████| 13/13 [00:00<00:00, 235.38it/s]
# 100%|██████████| 3/3 [00:00<00:00, 220.19it/s]
# INFO:cellpose.train:>>> using channels [0, 0]
# INFO:cellpose.train:>>> normalizing {'lowhigh': None, 'percentile': None, 'normalize': True, 'norm3D': False, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# INFO:cellpose.train:>>> n_epochs=1000, n_train=13, n_test=3
# INFO:cellpose.train:>>> SGD, learning_rate=0.10000, weight_decay=0.00010, momentum=0.900
# INFO:cellpose.train:>>> saving model to /content/drive/MyDrive/cellpose-cell-counting/models/cyto3
# INFO:cellpose.train:0, train_loss=2.3845, test_loss=2.6739, LR=0.0000, time 0.66s
# INFO:cellpose.train:5, train_loss=2.2562, test_loss=2.3751, LR=0.0556, time 3.72s
# INFO:cellpose.train:10, train_loss=2.1359, test_loss=2.2778, LR=0.1000, time 6.94s
# INFO:cellpose.train:20, train_loss=1.9241, test_loss=2.0282, LR=0.1000, time 12.85s
# INFO:cellpose.train:30, train_loss=1.8253, test_loss=1.8959, LR=0.1000, time 18.87s
# INFO:cellpose.train:40, train_loss=1.7703, test_loss=1.8163, LR=0.1000, time 24.85s
# INFO:cellpose.train:50, train_loss=1.7422, test_loss=1.7932, LR=0.1000, time 30.61s
# INFO:cellpose.train:60, train_loss=1.7031, test_loss=1.7464, LR=0.1000, time 36.73s
# INFO:cellpose.train:70, train_loss=1.6086, test_loss=1.7943, LR=0.1000, time 42.45s
# INFO:cellpose.train:80, train_loss=1.6652, test_loss=1.6994, LR=0.1000, time 48.38s
# INFO:cellpose.train:90, train_loss=1.6554, test_loss=1.6492, LR=0.1000, time 54.16s
# INFO:cellpose.train:100, train_loss=1.5901, test_loss=1.6244, LR=0.1000, time 59.93s
# INFO:cellpose.train:110, train_loss=1.6875, test_loss=1.6137, LR=0.1000, time 66.59s
# INFO:cellpose.train:120, train_loss=1.5515, test_loss=1.6599, LR=0.1000, time 72.72s
# INFO:cellpose.train:130, train_loss=1.5872, test_loss=1.6426, LR=0.1000, time 78.78s
# INFO:cellpose.train:140, train_loss=1.6078, test_loss=1.6292, LR=0.1000, time 84.54s
# INFO:cellpose.train:150, train_loss=1.5726, test_loss=1.5803, LR=0.1000, time 90.62s
# INFO:cellpose.train:160, train_loss=1.6144, test_loss=1.5892, LR=0.1000, time 96.47s
# INFO:cellpose.train:170, train_loss=1.6061, test_loss=1.6200, LR=0.1000, time 102.42s
# INFO:cellpose.train:180, train_loss=1.5497, test_loss=1.6109, LR=0.1000, time 108.45s
# INFO:cellpose.train:190, train_loss=1.5508, test_loss=1.5784, LR=0.1000, time 114.25s
# INFO:cellpose.train:200, train_loss=1.5818, test_loss=1.5822, LR=0.1000, time 120.30s
# INFO:cellpose.train:210, train_loss=1.5511, test_loss=1.6082, LR=0.1000, time 126.22s
# INFO:cellpose.train:220, train_loss=1.4918, test_loss=1.5703, LR=0.1000, time 132.21s
# INFO:cellpose.train:230, train_loss=1.5345, test_loss=1.5645, LR=0.1000, time 138.11s
# INFO:cellpose.train:240, train_loss=1.5547, test_loss=1.5704, LR=0.1000, time 143.95s
# INFO:cellpose.train:250, train_loss=1.5464, test_loss=1.5837, LR=0.1000, time 149.90s
# INFO:cellpose.train:260, train_loss=1.5511, test_loss=1.5542, LR=0.1000, time 155.65s
# INFO:cellpose.train:270, train_loss=1.5614, test_loss=1.5391, LR=0.1000, time 161.77s
# INFO:cellpose.train:280, train_loss=1.4793, test_loss=1.5837, LR=0.1000, time 167.54s
# INFO:cellpose.train:290, train_loss=1.5165, test_loss=1.5582, LR=0.1000, time 173.46s
# INFO:cellpose.train:300, train_loss=1.5653, test_loss=1.5070, LR=0.1000, time 179.42s
# INFO:cellpose.train:310, train_loss=1.5164, test_loss=1.5247, LR=0.1000, time 185.26s
# INFO:cellpose.train:320, train_loss=1.5003, test_loss=1.5210, LR=0.1000, time 191.85s
# INFO:cellpose.train:330, train_loss=1.4968, test_loss=1.5226, LR=0.1000, time 198.24s
# INFO:cellpose.train:340, train_loss=1.5566, test_loss=1.5405, LR=0.1000, time 204.25s
# INFO:cellpose.train:350, train_loss=1.5036, test_loss=1.5672, LR=0.1000, time 210.22s
# INFO:cellpose.train:360, train_loss=1.5222, test_loss=1.5280, LR=0.1000, time 216.03s
# INFO:cellpose.train:370, train_loss=1.5263, test_loss=1.5413, LR=0.1000, time 222.10s
# INFO:cellpose.train:380, train_loss=1.4543, test_loss=1.5260, LR=0.1000, time 227.83s
# INFO:cellpose.train:390, train_loss=1.5003, test_loss=1.5436, LR=0.1000, time 233.80s
# INFO:cellpose.train:400, train_loss=1.5280, test_loss=1.5614, LR=0.1000, time 239.68s
# INFO:cellpose.train:410, train_loss=1.5131, test_loss=1.5480, LR=0.1000, time 245.67s
# INFO:cellpose.train:420, train_loss=1.4596, test_loss=1.5402, LR=0.1000, time 251.64s
# INFO:cellpose.train:430, train_loss=1.5635, test_loss=1.5677, LR=0.1000, time 257.40s
# INFO:cellpose.train:440, train_loss=1.4223, test_loss=1.5167, LR=0.1000, time 263.54s
# INFO:cellpose.train:450, train_loss=1.4614, test_loss=1.5515, LR=0.1000, time 269.30s
# INFO:cellpose.train:460, train_loss=1.4602, test_loss=1.5190, LR=0.1000, time 275.28s
# INFO:cellpose.train:470, train_loss=1.5194, test_loss=1.5154, LR=0.1000, time 281.06s
# INFO:cellpose.train:480, train_loss=1.4755, test_loss=1.5222, LR=0.1000, time 286.88s
# INFO:cellpose.train:490, train_loss=1.4344, test_loss=1.5182, LR=0.1000, time 292.88s
# INFO:cellpose.train:500, train_loss=1.4946, test_loss=1.5419, LR=0.1000, time 298.61s
# INFO:cellpose.train:510, train_loss=1.5158, test_loss=1.5504, LR=0.1000, time 304.84s
# INFO:cellpose.train:520, train_loss=1.4824, test_loss=1.5326, LR=0.1000, time 310.65s
# INFO:cellpose.train:530, train_loss=1.4937, test_loss=1.5206, LR=0.1000, time 316.57s
# INFO:cellpose.train:540, train_loss=1.4744, test_loss=1.4758, LR=0.1000, time 322.46s
# INFO:cellpose.train:550, train_loss=1.4038, test_loss=1.5030, LR=0.1000, time 328.27s
# INFO:cellpose.train:560, train_loss=1.5086, test_loss=1.5053, LR=0.1000, time 334.37s
# INFO:cellpose.train:570, train_loss=1.4849, test_loss=1.4812, LR=0.1000, time 340.09s
# INFO:cellpose.train:580, train_loss=1.4615, test_loss=1.5201, LR=0.1000, time 346.30s
# INFO:cellpose.train:590, train_loss=1.4470, test_loss=1.5078, LR=0.1000, time 352.13s
# INFO:cellpose.train:600, train_loss=1.4668, test_loss=1.4823, LR=0.1000, time 358.00s
# INFO:cellpose.train:610, train_loss=1.4845, test_loss=1.4734, LR=0.1000, time 364.17s
# INFO:cellpose.train:620, train_loss=1.4621, test_loss=1.5082, LR=0.1000, time 369.94s
# INFO:cellpose.train:630, train_loss=1.4773, test_loss=1.5120, LR=0.1000, time 375.99s
# INFO:cellpose.train:640, train_loss=1.4114, test_loss=1.4989, LR=0.1000, time 381.72s
# INFO:cellpose.train:650, train_loss=1.5354, test_loss=1.5235, LR=0.1000, time 387.71s
# INFO:cellpose.train:660, train_loss=1.4128, test_loss=1.5268, LR=0.1000, time 393.51s
# INFO:cellpose.train:670, train_loss=1.4046, test_loss=1.5399, LR=0.1000, time 399.38s
# INFO:cellpose.train:680, train_loss=1.4884, test_loss=1.5364, LR=0.1000, time 405.34s
# INFO:cellpose.train:690, train_loss=1.4985, test_loss=1.5626, LR=0.1000, time 411.06s
# INFO:cellpose.train:700, train_loss=1.4795, test_loss=1.5627, LR=0.1000, time 417.22s
# INFO:cellpose.train:710, train_loss=1.4671, test_loss=1.5566, LR=0.1000, time 423.15s
# INFO:cellpose.train:720, train_loss=1.4625, test_loss=1.5144, LR=0.1000, time 429.16s
# INFO:cellpose.train:730, train_loss=1.4580, test_loss=1.5232, LR=0.1000, time 435.02s
# INFO:cellpose.train:740, train_loss=1.4380, test_loss=1.5227, LR=0.1000, time 441.00s
# INFO:cellpose.train:750, train_loss=1.4571, test_loss=1.5253, LR=0.1000, time 447.27s
# INFO:cellpose.train:760, train_loss=1.4947, test_loss=1.5037, LR=0.1000, time 454.00s
# INFO:cellpose.train:770, train_loss=1.4575, test_loss=1.5165, LR=0.1000, time 460.12s
# INFO:cellpose.train:780, train_loss=1.4751, test_loss=1.5385, LR=0.1000, time 465.95s
# INFO:cellpose.train:790, train_loss=1.4600, test_loss=1.5149, LR=0.1000, time 472.03s
# INFO:cellpose.train:800, train_loss=1.4547, test_loss=1.5043, LR=0.1000, time 477.90s
# INFO:cellpose.train:810, train_loss=1.4403, test_loss=1.5385, LR=0.1000, time 484.01s
# INFO:cellpose.train:820, train_loss=1.4357, test_loss=1.5484, LR=0.1000, time 490.00s
# INFO:cellpose.train:830, train_loss=1.4995, test_loss=1.5390, LR=0.1000, time 495.81s
# INFO:cellpose.train:840, train_loss=1.4807, test_loss=1.5158, LR=0.1000, time 501.96s
# INFO:cellpose.train:850, train_loss=1.4243, test_loss=1.5173, LR=0.1000, time 507.70s
# INFO:cellpose.train:860, train_loss=1.4303, test_loss=1.5229, LR=0.1000, time 513.79s
# INFO:cellpose.train:870, train_loss=1.4661, test_loss=1.5469, LR=0.1000, time 519.61s
# INFO:cellpose.train:880, train_loss=1.5470, test_loss=1.5237, LR=0.1000, time 525.49s
# INFO:cellpose.train:890, train_loss=1.3905, test_loss=1.5213, LR=0.1000, time 531.49s
# INFO:cellpose.train:900, train_loss=1.4138, test_loss=1.5346, LR=0.0500, time 537.28s
# INFO:cellpose.train:910, train_loss=1.4340, test_loss=1.5228, LR=0.0250, time 543.56s
# INFO:cellpose.train:920, train_loss=1.4337, test_loss=1.5255, LR=0.0125, time 549.31s
# INFO:cellpose.train:930, train_loss=1.5049, test_loss=1.5210, LR=0.0063, time 555.39s
# INFO:cellpose.train:940, train_loss=1.4161, test_loss=1.5143, LR=0.0031, time 561.27s
# INFO:cellpose.train:950, train_loss=1.4595, test_loss=1.5052, LR=0.0016, time 567.00s
# INFO:cellpose.train:960, train_loss=1.4009, test_loss=1.5080, LR=0.0008, time 573.05s
# INFO:cellpose.train:970, train_loss=1.4547, test_loss=1.5019, LR=0.0004, time 579.40s
# INFO:cellpose.train:980, train_loss=1.3992, test_loss=1.5020, LR=0.0002, time 586.68s
# INFO:cellpose.train:990, train_loss=1.4381, test_loss=1.5044, LR=0.0001, time 592.48s

# %% [markdown]
# #Testing with the dataset where the cell counts are needed.

# %%
CELL_COUNTING_FOLDER_NAME = "2024.05.09. Ac-kPHSRN+fibronektin"
MODEL_NAME = "cyto3"

# !unzip "/content/drive/MyDrive/{CELL_COUNTING_FOLDER_NAME}.zip" -d "/content"

# %%
import numpy as np
from torch.utils.data import Dataset
import glob
import cv2

file_names = glob.glob(CELL_COUNTING_FOLDER_NAME + "/*.jpg")

class CellCountingDataset(Dataset):
  def __len__(self):
    return len(file_names)

  def __getitem__(self, idx):
    img = cv2.imread(file_names[idx], 0)
    return img

dataset = CellCountingDataset()

# %%
from cellpose import models
import torch

model = models.CellposeModel(
    pretrained_model=f"/content/drive/MyDrive/cellpose-cell-counting/models/{MODEL_NAME}",
    gpu=torch.cuda.is_available())

# %%
import matplotlib.pyplot as plt

# Increase this flow threshold if cellpose is not returning as many ROIs as you’d expect.
# Similarly, decrease this threshold if cellpose is returning too many ill-shaped ROIs.
#
# Decrease cellprob threshold if cellpose is not returning as many ROIs as you’d expect.
# Similarly, increase this threshold if cellpose is returning too ROIs particularly from dim areas.
FLOW_THRESHOLD = 0.4
CELLPROB_THRESHOLD = 0.0

NUM_EXAMPLES = 5
ids = np.random.randint(0, len(dataset), size=NUM_EXAMPLES)

fig, ax = plt.subplots(nrows=NUM_EXAMPLES, ncols=2, dpi=300)
fig.tight_layout()

for i in range(NUM_EXAMPLES):
  mask, _, _ = model.eval(
      dataset[ids[i]],
      diameter=None,
      channels=[0, 0],
      flow_threshold=FLOW_THRESHOLD,
      cellprob_threshold=CELLPROB_THRESHOLD)

  cell_cnt = np.max(mask)

  ax[i][0].title.set_text(f"{cell_cnt} cells")
  ax[i][0].axis("off")
  ax[i][0].imshow(dataset[ids[i]], cmap="gray");

  ax[i][1].axis("off")
  ax[i][1].imshow(mask)

# %% [markdown]
# # Generating masks and cell counts for images.

# %%
# Increase this flow threshold if cellpose is not returning as many ROIs as you’d expect.
# Similarly, decrease this threshold if cellpose is returning too many ill-shaped ROIs.
#
# Decrease cellprob threshold if cellpose is not returning as many ROIs as you’d expect.
# Similarly, increase this threshold if cellpose is returning too ROIs particularly from dim areas.
FLOW_THRESHOLD = 0.4
CELLPROB_THRESHOLD = 0.0

# %%
imgs = []
for data in dataset:
  imgs.append(data)

masks, _, _ = model.eval(
    imgs,
    diameter=20,
    channels=[0, 0],
    flow_threshold=FLOW_THRESHOLD,
    cellprob_threshold=CELLPROB_THRESHOLD)

# %%
import cv2
import os
import csv

save_dir = "/content/result"
cnts = {}

for img, mask, file_name in zip(imgs, masks, file_names):
  bgr_image = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
  contours, _ = cv2.findContours(np.array(mask, dtype=np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cv2.drawContours(bgr_image, contours, -1, (0, 255, 0), 2)

  if not os.path.exists(save_dir):
    os.makedirs(save_dir)

  file_name = file_name.split("/")[1]

  cv2.imwrite(os.path.join(save_dir, file_name), bgr_image)
  cnts[file_name] = np.max(mask)

with open(os.path.join(save_dir, "result.csv"),'w') as f:
  w = csv.writer(f, delimiter=";")
  w.writerows(cnts.items())

# %%
# !zip -r /content/result.zip /content/result
